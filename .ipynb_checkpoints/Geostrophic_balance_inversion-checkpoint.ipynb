# %% [markdown]
# # Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import Util as ut
import jax.numpy as jnp
from jax import grad, jit, vmap
from functools import partial

# %% [markdown]
# # Reading data

# %% [markdown]
# ## Parameters

# %%
#dir_data = '/home/viannazv/notebooks/Data/'
#name_mask = 'mask_eNATL60MEDWEST_3.6.nc'
#name_coord = 'coordinates_eNATL60MEDWEST.nc'
#name_ssh = 'eNATL60MEDWEST-BLB002_y2009m07d01.1h_sossheig.nc'
#name_u = 'eNATL60MEDWEST-BLB002_y2009m07d01.1h_sozocrtx.nc'
#name_v = 'eNATL60MEDWEST-BLB002_y2009m07d01.1h_somecrty.nc'

dir_data = '/home/viannazv/notebooks/Data/Data2/'
name_ssh = 'NATLORCA12.L75-GJM2020_y2015m12d31.1d_gridT.nc'
name_u = 'NATLORCA12.L75-GJM2020_y2015m12d31.1d_gridU.nc'
name_v = 'NATLORCA12.L75-GJM2020_y2015m12d31.1d_gridV.nc'

# %% [markdown]
# ## Opening data

# %%
#ds_coord = xr.open_dataset(dir_data+name_coord)
#lon = ds_coord.nav_lon.values
#lat = ds_coord.nav_lat.values

#ds_mask = xr.open_dataset(dir_data+name_mask)
#mask_ssh = ds_mask.tmask[0,0].values
#mask_u = ds_mask.umask[0,0].values
#mask_v = ds_mask.vmask[0,0].values

ds_ssh = xr.open_dataset(dir_data+name_ssh)
#print(ds_ssh)
lon_ssh = ds_ssh.nav_lon.values
lat_ssh = ds_ssh.nav_lat.values
ssh = ds_ssh.sossheig[0].values

ds_u = xr.open_dataset(dir_data+name_u)
#print(ds_u)
lon_u = ds_u.nav_lon.values
lat_u = ds_u.nav_lat.values
uvel = ds_u.vozocrtx[0,0].values

ds_v = xr.open_dataset(dir_data+name_v)
#print(ds_v)
lon_v = ds_v.nav_lon.values
lat_v = ds_v.nav_lat.values
vvel = ds_v.vomecrty[0,0].values

# %% [markdown]
# ## Ploting the data

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, uvel,shading='auto')
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v, lat_v,vvel,shading='auto')
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_ssh, lat_ssh,ssh,shading='auto')
plt.colorbar(im,ax=ax3)
plt.show()
# Out:
# /tmp/ipykernel_32145/3057717042.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_u, lat_u, uvel,shading='auto')
# /tmp/ipykernel_32145/3057717042.py:8: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax2.pcolormesh(lon_v, lat_v,vvel,shading='auto')
# /tmp/ipykernel_32145/3057717042.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax3.pcolormesh(lon_ssh, lat_ssh,ssh,shading='auto')

# %% [markdown]
#  ## Spliting the data for the geostrophy

# %%
#x1 =180
#x2 = -480
#y1 = 500
#y2 = -100

# Reduced grid for testing
#x1 =180
#x2 = -615
#y1 = 500
#y2 = -375



#x1 =10
#x2 = -10
#y1 = 10
#y2 = -10


x1 =230
x2 = -750
y1 = 650
y2 = -850


ssh = ssh[x1-1 : x2+1, y1-1 : y2+1]
lat_ssh = lat_ssh[x1-1 : x2+1, y1-1 : y2+1]
lon_ssh = lon_ssh[x1-1 : x2+1, y1-1 : y2+1]

uvel = uvel[x1 : x2, y1-1 : y2]
lat_u = lat_u[x1 : x2, y1-1 : y2]
lon_u = lon_u[x1 : x2, y1-1 : y2]

vvel = vvel[x1-1 : x2, y1 : y2]
lat_v = lat_v[x1-1 : x2, y1 : y2]
lon_v = lon_v[x1-1 : x2, y1 : y2]

# %% [markdown]
# ## Ploting the split data

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, uvel,shading='auto')
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v,lat_v,vvel,shading='auto')
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_ssh, lat_ssh,ssh,shading='auto')
plt.colorbar(im,ax=ax3)
plt.show()
# Out:
# /tmp/ipykernel_32145/77493372.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_u, lat_u, uvel,shading='auto')
# /tmp/ipykernel_32145/77493372.py:8: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax2.pcolormesh(lon_v,lat_v,vvel,shading='auto')
# /tmp/ipykernel_32145/77493372.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax3.pcolormesh(lon_ssh, lat_ssh,ssh,shading='auto')

# %% [markdown]
# ## Plotting the C-Grid"

# %%
fig = ut.PlotGrid(lon_ssh, lat_ssh, lon_u, lat_u, lon_v, lat_v)

# %% [markdown]
# # Input data

# %%
gravity = 9.81 #[m/s2]
coriolis_factor_ssh = 2 * 7.2722e-05 * np.sin(lat_ssh * np.pi / 180)
coriolis_factor_u = 2 * 7.2722e-05 * np.sin(lat_u * np.pi / 180)
coriolis_factor_v = 2 * 7.2722e-05 * np.sin(lat_v * np.pi / 180)

# %% [markdown]
# # Geostrophic  balance

# %% [markdown]
# ## Gradient of the SSH

# %%
grad_ssh_x, grad_ssh_y = ut.compute_gradient(ssh, lon_ssh, lat_ssh)

# %% [markdown]
# ## Interpolation of the data (moving the grad into the u and v position)

# %%
grad_ssh_y = ut.interpolate_y(grad_ssh_y)
grad_ssh_y = ut.interpolate_x(grad_ssh_y)

grad_ssh_x = ut.interpolate_x(grad_ssh_x)
grad_ssh_x = ut.interpolate_y(grad_ssh_x)

# %% [markdown]
# ## Geostrophic velocities

# %%
u_geos = - gravity * grad_ssh_y / coriolis_factor_u
v_geos =   gravity * grad_ssh_x / coriolis_factor_v

# %% [markdown]
# ## Ploting the u_geos and v_geos

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, uvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_u,lat_u,u_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_u, lat_u,uvel-u_geos, cmap='RdBu',shading='auto',vmin=-0.3, vmax=0.3)
plt.colorbar(im,ax=ax3)

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_v, lat_v, vvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v,lat_v,v_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_v, lat_v,vvel-v_geos, cmap='RdBu',shading='auto',vmin=-0.3, vmax=0.3)
plt.colorbar(im,ax=ax3)
# Out:
# /tmp/ipykernel_32145/2483783472.py:6: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_u, lat_u, uvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
# /tmp/ipykernel_32145/2483783472.py:8: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax2.pcolormesh(lon_u,lat_u,u_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
# /tmp/ipykernel_32145/2483783472.py:10: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax3.pcolormesh(lon_u, lat_u,uvel-u_geos, cmap='RdBu',shading='auto',vmin=-0.3, vmax=0.3)
# /tmp/ipykernel_32145/2483783472.py:18: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_v, lat_v, vvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
# /tmp/ipykernel_32145/2483783472.py:20: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax2.pcolormesh(lon_v,lat_v,v_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
# /tmp/ipykernel_32145/2483783472.py:22: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax3.pcolormesh(lon_v, lat_v,vvel-v_geos, cmap='RdBu',shading='auto',vmin=-0.3, vmax=0.3)

# %% [markdown]
# # Cyclogeostrophic balance

# %%
adv_u = ut.compute_advection_u(u_geos, v_geos, lon_u, lat_u)
adv_v = ut.compute_advection_v(u_geos, v_geos, lon_v, lat_v)

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, uvel-u_geos, cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_u,lat_u,adv_u/coriolis_factor_v[1:-1,:], cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)
plt.colorbar(im,ax=ax2)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_v, lat_v, vvel-v_geos, cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v,lat_v,adv_v/coriolis_factor_u[:,1:-1], cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)
plt.colorbar(im,ax=ax2)
# Out:
# /tmp/ipykernel_32145/852821721.py:5: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_u, lat_u, uvel-u_geos, cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)
# /tmp/ipykernel_32145/852821721.py:14: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   im = ax1.pcolormesh(lon_v, lat_v, vvel-v_geos, cmap='RdBu',shading='auto',vmin=-0.1, vmax=0.1)

# %% [markdown]
# ## Resize of the grid
#
# Due to the interpolation of the advection term, the grid has to be reduced.

# %%
# =============================================================================
# Ploting the advection u in the mesh (v point)
# =============================================================================

dudx_lon = ut.interpolate_x(lon_u)
dudx_lat = ut.interpolate_x(lat_u)

dudx_lon = ut.interpolate_y(dudx_lon)
dudx_lat = ut.interpolate_y(dudx_lat)

dudy_lon = ut.interpolate_y(lon_u)
dudy_lat = ut.interpolate_y(lat_u)

dudy_lon = ut.interpolate_x(dudy_lon)
dudy_lat = ut.interpolate_x(dudy_lat)

u_lon_int = ut.interpolate_x(lon_u)
u_lat_int = ut.interpolate_x(lat_u)

u_lon_int = ut.interpolate_y(u_lon_int)
u_lat_int = ut.interpolate_y(u_lat_int)

plt.figure()
plt.scatter(lon_ssh, lat_ssh, label='SSH', zorder=2)
plt.scatter(lon_u, lat_u,label='u', zorder=1)
plt.scatter(lon_v, lat_v, label='v',zorder=1)
plt.scatter(dudx_lon, dudx_lat, label='du/dx',zorder=4)
# plt.scatter(dudy_lon, dudy_lat, label='du/dy',zorder=3,c ='purple')
# plt.scatter(u_lon_int, u_lat_int, label='u_int',zorder=3, c ='cyan')
plt.xlim(2.715,2.8)
plt.ylim(37.275,37.34)
plt.xlabel('longitude [degrees]')
plt.ylabel('latitude [degrees]')
plt.legend(loc=1,framealpha =1)
plt.show()

# %%
# =============================================================================
# Ploting the advection v in the mesh (u point)
# =============================================================================

dvdx_lon = ut.interpolate_x(lon_v)
dvdx_lat = ut.interpolate_x(lat_v)

dvdx_lon = ut.interpolate_y(dvdx_lon)
dvdx_lat = ut.interpolate_y(dvdx_lat)

dvdy_lon = ut.interpolate_y(lon_v)
dvdy_lat = ut.interpolate_y(lat_v)

dvdy_lon = ut.interpolate_x(dvdy_lon)
dvdy_lat = ut.interpolate_x(dvdy_lat)

v_lon_int = ut.interpolate_x(lon_v)
v_lat_int = ut.interpolate_x(lat_v)

v_lon_int = ut.interpolate_y(v_lon_int)
v_lat_int = ut.interpolate_y(v_lat_int)

plt.figure()
plt.scatter(lon_ssh, lat_ssh, label='SSH', zorder=2)
plt.scatter(lon_u, lat_u,label='u', zorder=1)
plt.scatter(lon_v, lat_v, label='v',zorder=1)
# plt.scatter(dvdx_lon, dvdx_lat, label='dv/dx',zorder=4)
# plt.scatter(dvdy_lon, dvdy_lat, label='dv/dy',zorder=3,c ='purple')
plt.scatter(v_lon_int, v_lat_int, label='v_int',zorder=3, c ='cyan')
plt.xlim(2.715,2.8)
plt.ylim(37.275,37.34)
plt.xlabel('longitude [degrees]')
plt.ylabel('latitude [degrees]')
plt.legend(loc=1,framealpha =1)
plt.show()

# %%
u_geos_r = u_geos[:,1:-1]
v_geos_r = v_geos[1:-1,:]

coriolis_factor_ssh = coriolis_factor_ssh[1:-1,1:-1]
coriolis_factor_u = coriolis_factor_u[:,1:-1]
coriolis_factor_v = coriolis_factor_v[1:-1,:]

# %% [markdown]
# ## Iterative method

# %%
u_cy,v_cy = ut.compute_cyclogeostrophy(u_geos, v_geos, coriolis_factor_u, coriolis_factor_v, lon_u, lat_u, lon_v, lat_v, 0.01)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_32145/3569123741.py in <module>
# ----> 1 u_cy,v_cy = ut.compute_cyclogeostrophy(u_geos, v_geos, coriolis_factor_u, coriolis_factor_v, lon_u, lat_u, lon_v, lat_v, 0.01)
#
# ~/notebooks/cyclogeostrophic-balance/Util.py in compute_cyclogeostrophy(ug, vg, coriolis_u, coriolis_v, lon_u, lat_u, lon_v, lat_v, epsilon)
#     247         u_jnp1 = ug[:,1:-1] + (1/coriolis_u)*advec_v
#     248         v_jnp1 = vg[1:-1,:] - (1/coriolis_v)*advec_u
# --> 249         errsq = np.sum(np.square(u_jnp1-u_n)) + np.sum(np.square(v_jnp1-v_n))
#     250         mask_jnp1 = np.where(errsq < arreps, 1, 0)
#     251         mask_n = np.where(errsq > errsq_n, 1, 0)
#
# ValueError: operands could not be broadcast together with shapes (11,15) (11,17)

# %% [markdown]
# ## Defining the cost function

# %%
# Input values for the loss function
u = u_geos
v = v_geos

# %%
# Cost function using a lambda function
J_u = lambda x,y: jnp.sum(((x[:,1:-1] + ut.compute_advection_v_jax(x, y, lon_v, lat_v)/coriolis_factor_u)*x[:,1:-1] - x[:,1:-1]*u_geos_r)**2)
J_v = lambda x,y: jnp.sum(((y[1:-1,:] - ut.compute_advection_u_jax(x, y, lon_u, lat_u)/coriolis_factor_v)*y[1:-1,:] - y[1:-1,:]*v_geos_r)**2)

J = lambda x,y: J_u(x,y) + J_v(x,y)

# Initial loss
J(u,v)

# %%
# Cost function using a normal function
def loss(u,v):
    J_u = np.sum((u[:,1:-1] + ut.compute_advection_v(u, v, lon_v, lat_v)/coriolis_factor_u*u[:,1:-1] - u_geos_r)**2) 
    J_v = np.sum((v[1:-1,:] - ut.compute_advection_u(u, v, lon_u, lat_u)/coriolis_factor_v*v[1:-1,:] - v_geos_r)**2)

    J = J_u + J_v
    
    return J

# Initial loss
loss(u,v)

# %% [markdown]
# ## Minimization algorithm - Gradient descent

# %%
@partial(jit,static_argnums=(2,))
def iteration(x,y,f):
    x = jnp.asarray(x)
    y = jnp.asarray(y)
    grad_x = grad(f)
    grad_y = grad(f,argnums=(1))

    #update x and y using gradient descent
    x = x - 0.01 * grad_x(x,y)
    y = y - 0.01 * grad_y(x,y)
    
    return x,y

iteration(u,v,J)

# %%
def gradient_descent_jax(f, x_init, y_init, learning_rate = 0.01, num_iterations = 1000):

    x, y = x_init, y_init
    
    fig = plt.subplot()
    
    for i in range(num_iterations):
        
        # calculate the gradient of f at (x, y)
        x,y = iteration(x,y,f)
        
        fig.scatter(i,f(x,y),color = 'blue')
        
        # print the current value of f and (x, y)
        print("iteration {}: f(x, y) = {}".format(i, f(x, y)))
    return x, y
        
u_min, v_min = gradient_descent_jax(J,u,v)

# %%
def gradient_descent(f, x_init, y_init, learning_rate = 0.01, num_iterations = 10):

    x, y = x_init, y_init
    
    # calculate the gradient of f at (x, y)
    grad_x = grad(f)
    grad_y = grad(f,argnums=(1))
    
    for i in range(num_iterations):
        # update x and y using gradient descent
        x = x - learning_rate * grad_x(x,y)
        y = y - learning_rate * grad_y(x,y)

        # print the current value of f and (x, y)
        print("iteration {}: f(x, y) = {}".format(i, f(x, y)))
        
    return x, y

# run gradient descent to minimize f
u_min, v_min = gradient_descent(J,u,v)

# %% [markdown]
# ## Ploting u_geos v_geos and u v minimized

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, u_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_u,lat_u,u_min, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_u, lat_u,u_geos-u_min, cmap='RdBu',shading='auto',vmin=-0.4, vmax=0.4)
plt.colorbar(im,ax=ax3)

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_v, lat_v, v_geos, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v,lat_v,v_min, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_v, lat_v,v_geos-v_min, cmap='RdBu',shading='auto',vmin=-0.04, vmax=0.04)
plt.colorbar(im,ax=ax3)

# %% [markdown]
# ## Ploting u v from eNATL60 and u v minimized

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_u, lat_u, uvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_u,lat_u,u_min, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_u, lat_u,uvel-u_min, cmap='RdBu',shading='auto',vmin=-0.09, vmax=0.09)
plt.colorbar(im,ax=ax3)

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.set_xlabel('longitude \n (a)')
ax2.set_xlabel('longitude \n (b)')
ax3.set_xlabel('longitude \n (c)')
ax1.set_ylabel('latitude')
im = ax1.pcolormesh(lon_v, lat_v, vvel, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax1)
im = ax2.pcolormesh(lon_v,lat_v,v_min, cmap='RdBu',shading='auto',vmin=-0.9, vmax=0.9)
plt.colorbar(im,ax=ax2)
im = ax3.pcolormesh(lon_v, lat_v,vvel-v_min, cmap='RdBu',shading='auto',vmin=-0.09, vmax=0.09)
plt.colorbar(im,ax=ax3)

# %%
u = jnp.asarray(u_geos)
v = jnp.asarray(v_geos)

# %%
ut.compute_advection_v_jax(u, v, lon_v, lat_v)

# %%
# %timeit ut.compute_advection_v_jax(u, v, lon_v, lat_v)
